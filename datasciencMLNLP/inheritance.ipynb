# %% [markdown]
# inheritance in Python
# Inheritance in  python is a fundamental concept in Object-Oriented Programming (OOP) that allow a class to inherit attribes and methods from another class.this lesson covers single inheritence and multiply inheritence,demonstrating how to create and use them in python.

# %%
# Inheritance(single)
## Parent class
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
        
    def drive(self):
        print(f"The person will drive the {self.enginetype} car")

# %%
car1=Car(4,5,"Petrol")
car1.drive()
# Out:
# The person will drive the Petrol car

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdrive):
        super().__init__(windows,doors,enginetype)
        self.is_selfdrive=is_selfdrive
    
    def selfdrive(self):
        print(f"Tesla supports self driving {self.is_selfdrive}")

tesla1=Tesla(4,5,"electric",True)
tesla1.selfdrive()
# Out:
# Tesla supports self driving True

# %%
##multiple inheritance

## when a class inherite more than one base class:

class Animal:
    def __init__(self,name):
        self.name=name
    def speak(self):
        print("sucalss must impliment this method")
    
##Base class 2:
class Pet:
    def __init__(self,owner):
        self.owner=owner
    
##Derive class:
class Dog(Animal,Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)
        
    def speak(self):
        return f"{self.name} says woof"
##create an Object
dog=Dog("Buddy","Krish")
print(dog.speak())
print(f"Owner: {dog.owner}")
# Out:
# Buddy says woof
# Owner: Krish
